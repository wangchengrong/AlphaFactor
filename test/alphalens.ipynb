# %%
import pandas as pd
import alphalens
# Out:
# /Users/polo/anaconda3/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import matplotlib.pyplot as plt

# %%
factor_data = pd.read_pickle('factor_data.pkl')

# %%
factor_data.head()
# Out:
#                           1         5        10    factor group  \
# date       asset
# 2016-01-04 000001  0.008861 -0.047807 -0.078766   9.77590    深圳
#            000002  0.000000  0.000000  0.000000  20.74945    深圳
#            000008  0.016957 -0.083749 -0.127932  11.69370    北京
#            000060 -0.036438 -0.090257 -0.197177  14.42065    深圳
#            000063  0.018960 -0.084567 -0.104129  18.07875    深圳
#
#                    factor_quantile
# date       asset
# 2016-01-04 000001                2
#            000002                4
#            000008                3
#            000060                3
#            000063                4

# %%
alphalens.tears.create_returns_tear_sheet(factor_data, by_group=True)
plt.show()
# Out:
# Returns Analysis
#                                                   1      5      10
# Ann. alpha                                     0.030  0.040  0.049
# beta                                          -0.004 -0.000  0.004
# Mean Period Wise Return Top Quantile (bps)     0.721  1.060  1.308
# Mean Period Wise Return Bottom Quantile (bps)  2.058  1.549  1.238
# Mean Period Wise Spread (bps)                 -1.548 -0.617 -0.017
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/utils.py:530: FutureWarning: pd.rolling_apply is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=5,min_periods=1).apply(func=<function>,kwargs=<dict>,args=<tuple>)
#   args=(period,))
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/utils.py:530: FutureWarning: pd.rolling_apply is deprecated for DataFrame and will be removed in a future version, replace with
# ...

# %%
alphalens.tears.create_information_tear_sheet(factor_data, by_group=True)
# Out:
# Information Analysis
#                 1      5      10
# IC Mean     -0.003  0.001  0.004
# IC Std.      0.159  0.183  0.197
# t-stat(IC)  -0.434  0.164  0.423
# p-value(IC)  0.665  0.870  0.672
# IC Skew     -0.083 -0.040 -0.079
# IC Kurtosis -0.463 -0.784 -0.923
# Ann. IR     -0.312  0.118  0.304
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/plotting.py:217: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=22,center=False).mean()
#   pd.rolling_mean(ic, 22).plot(ax=a,
# /Users/polo/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3167: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/polo/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3168: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# ...

# %%
plt.show()

# %%
alphalens.tears.create_turnover_tear_sheet(factor_data)
# Out:
# Turnover Analysis
#                                1      5     10
# Quantile 1 Mean Turnover   0.002  0.011  0.019
# Quantile 2 Mean Turnover   0.006  0.024  0.043
# Quantile 3 Mean Turnover   0.007  0.026  0.046
# Quantile 4 Mean Turnover   0.006  0.023  0.042
# Quantile 5 Mean Turnover   0.003  0.012  0.023
#                                     1    5     10
# Mean Factor Rank Autocorrelation  1.0  1.0  0.999

# %%
plt.show()
