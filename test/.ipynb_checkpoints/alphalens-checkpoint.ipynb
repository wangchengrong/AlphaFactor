# %%
import pandas as pd
import alphalens
# Out:
# /Users/polo/anaconda3/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import matplotlib.pyplot as plt

# %%
factor_data = pd.read_pickle('factor_data.pkl')

# %%
factor_data.head()
# Out:
#                           1         5        10    factor group  \
# date       asset
# 2016-01-04 000001  0.008861 -0.047807 -0.078766   9.77590    江苏
#            000002  0.000000  0.000000  0.000000  20.74945    江苏
#            000008  0.016957 -0.083749 -0.127932  11.69370    江苏
#            000060 -0.036438 -0.090257 -0.197177  14.42065    江苏
#            000063  0.018960 -0.084567 -0.104129  18.07875    江苏
#
#                    factor_quantile
# date       asset
# 2016-01-04 000001                2
#            000002                4
#            000008                3
#            000060                3
#            000063                4

# %%
alphalens.tears.create_full_tear_sheet(factor_data)
plt.show()
# Out:
# Quantiles Statistics
#                       min        max       mean        std  count    count %
# factor_quantile
# 1                 1.99790    7.51435   4.829052   1.255072  27688  20.104706
# 2                 5.63225   11.53550   8.380359   1.233374  27475  19.950043
# 3                 8.62845   18.49750  13.152961   1.896134  27458  19.937699
# 4                13.13330   30.29600  20.046364   3.104808  27475  19.950043
# 5                20.49055  659.30500  46.319898  47.317533  27623  20.057508
# Returns Analysis
#                                                   1      5      10
# Ann. alpha                                     0.027  0.041  0.046
# beta                                          -0.003  0.001  0.001
# Mean Period Wise Return Top Quantile (bps)     0.709  1.305  1.430
# Mean Period Wise Return Bottom Quantile (bps)  2.136  1.387  1.091
# Mean Period Wise Spread (bps)                 -1.640 -0.225  0.242
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/utils.py:530: FutureWarning: pd.rolling_apply is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=5,min_periods=1,center=False).apply(kwargs=<dict>,func=<function>,args=<tuple>)
#   args=(period,))
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/utils.py:530: FutureWarning: pd.rolling_apply is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=10,min_periods=1,center=False).apply(kwargs=<dict>,func=<function>,args=<tuple>)
#   args=(period,))
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/plotting.py:522: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=22).mean()
#   pd.rolling_mean(mean_returns_spread_bps, 22).plot(color='orangered',
# Information Analysis
#                 1      5      10
# IC Mean     -0.003  0.004  0.006
# IC Std.      0.158  0.182  0.198
# t-stat(IC)  -0.450  0.424  0.680
# p-value(IC)  0.653  0.672  0.497
# IC Skew     -0.083 -0.056 -0.101
# IC Kurtosis -0.459 -0.765 -0.928
# Ann. IR     -0.327  0.308  0.493
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/plotting.py:217: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=22).mean()
#   pd.rolling_mean(ic, 22).plot(ax=a,
# /Users/polo/anaconda3/lib/python3.5/site-packages/alphalens/performance.py:113: FutureWarning: pd.TimeGrouper is deprecated and will be removed; Please use pd.Grouper(freq=...)
#   grouper.append(pd.TimeGrouper(by_time))
# Turnover Analysis
#                                1      5     10
# Quantile 1 Mean Turnover   0.004  0.016  0.028
# Quantile 2 Mean Turnover   0.008  0.035  0.061
# Quantile 3 Mean Turnover   0.010  0.039  0.070
# Quantile 4 Mean Turnover   0.009  0.036  0.065
# Quantile 5 Mean Turnover   0.004  0.018  0.031
#                                     1    5     10
# Mean Factor Rank Autocorrelation  1.0  1.0  0.999

# %%
factor_data.dtypes
# Out:
# 1                  float64
# 5                  float64
# 10                 float64
# factor             float64
# group               object
# factor_quantile      int64
# dtype: object
